# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report
from xgboost import XGBClassifier
import tensorflow as tf

# %% [markdown]
# # Data

# %%
raw_train_data = pd.read_csv("/kaggle/input/playground-series-s3e26/train.csv")
raw_test_data = pd.read_csv("/kaggle/input/playground-series-s3e26/test.csv")

# %%
raw_train_data
# Out:
#         id  N_Days             Drug    Age Sex Ascites Hepatomegaly Spiders  \
# 0        0     999  D-penicillamine  21532   M       N            N       N
# 1        1    2574          Placebo  19237   F       N            N       N
# 2        2    3428          Placebo  13727   F       N            Y       Y
# 3        3    2576          Placebo  18460   F       N            N       N
# 4        4     788          Placebo  16658   F       N            Y       N
# ...    ...     ...              ...    ...  ..     ...          ...     ...
# 7900  7900    1166  D-penicillamine  16839   F       N            N       N
# 7901  7901    1492          Placebo  17031   F       N            Y       N
# 7902  7902    1576  D-penicillamine  25873   F       N            N       Y
# 7903  7903    3584  D-penicillamine  22960   M       N            Y       N
# 7904  7904    1978  D-penicillamine  19237   F       N            N       N
#
#      Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 0        N        2.3        316.0     3.35   172.0    1601.0  179.80
# 1        N        0.9        364.0     3.54    63.0    1440.0  134.85
# 2        Y        3.3        299.0     3.55   131.0    1029.0  119.35
# 3        N        0.6        256.0     3.50    58.0    1653.0   71.30
# 4        N        1.1        346.0     3.65    63.0    1181.0  125.55
# ...    ...        ...          ...      ...     ...       ...     ...
# 7900     N        0.8        309.0     3.56    38.0    1629.0   79.05
# 7901     N        0.9        260.0     3.43    62.0    1440.0  142.00
# 7902     S        2.0        225.0     3.19    51.0     933.0   69.75
# 7903     N        0.7        248.0     2.75    32.0    1003.0   57.35
# 7904     N        0.7        256.0     3.23    22.0     645.0   74.40
#
#       Tryglicerides  Platelets  Prothrombin  Stage Status
# 0              63.0      394.0          9.7    3.0      D
# 1              88.0      361.0         11.0    3.0      C
# 2              50.0      199.0         11.7    4.0      D
# 3              96.0      269.0         10.7    3.0      C
# 4              96.0      298.0         10.6    4.0      C
# ...             ...        ...          ...    ...    ...
# 7900          224.0      344.0          9.9    2.0      C
# 7901           78.0      277.0         10.0    4.0      C
# 7902           62.0      200.0         12.7    2.0      D
# 7903          118.0      221.0         10.6    4.0      D
# 7904           85.0      336.0         10.3    3.0      C
#
# [7905 rows x 20 columns]

# %%
raw_train_data.isna().sum()
# Out:
# id               0
# N_Days           0
# Drug             0
# Age              0
# Sex              0
# Ascites          0
# Hepatomegaly     0
# Spiders          0
# Edema            0
# Bilirubin        0
# Cholesterol      0
# Albumin          0
# Copper           0
# Alk_Phos         0
# SGOT             0
# Tryglicerides    0
# Platelets        0
# Prothrombin      0
# Stage            0
# Status           0
# dtype: int64

# %%
y_train = raw_train_data["Status"]
X_train = raw_train_data.drop(columns=["id","Status"])

# %%
def convert_cat(x, cats):
    data = x.copy()
    for col in cats:
        le = LabelEncoder()
        data[col] = le.fit_transform(data[col])
    return data

# %%
le_cats = ["Drug","Sex","Ascites","Hepatomegaly","Spiders","Edema"]
X_train = convert_cat(X_train, le_cats)

# %%
X_train
# Out:
#       N_Days  Drug    Age  Sex  Ascites  Hepatomegaly  Spiders  Edema  \
# 0        999     0  21532    1        0             0        0      0
# 1       2574     1  19237    0        0             0        0      0
# 2       3428     1  13727    0        0             1        1      2
# 3       2576     1  18460    0        0             0        0      0
# 4        788     1  16658    0        0             1        0      0
# ...      ...   ...    ...  ...      ...           ...      ...    ...
# 7900    1166     0  16839    0        0             0        0      0
# 7901    1492     1  17031    0        0             1        0      0
# 7902    1576     0  25873    0        0             0        1      1
# 7903    3584     0  22960    1        0             1        0      0
# 7904    1978     0  19237    0        0             0        0      0
#
#       Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 0           2.3        316.0     3.35   172.0    1601.0  179.80
# 1           0.9        364.0     3.54    63.0    1440.0  134.85
# 2           3.3        299.0     3.55   131.0    1029.0  119.35
# 3           0.6        256.0     3.50    58.0    1653.0   71.30
# 4           1.1        346.0     3.65    63.0    1181.0  125.55
# ...         ...          ...      ...     ...       ...     ...
# 7900        0.8        309.0     3.56    38.0    1629.0   79.05
# 7901        0.9        260.0     3.43    62.0    1440.0  142.00
# 7902        2.0        225.0     3.19    51.0     933.0   69.75
# 7903        0.7        248.0     2.75    32.0    1003.0   57.35
# 7904        0.7        256.0     3.23    22.0     645.0   74.40
#
#       Tryglicerides  Platelets  Prothrombin  Stage
# 0              63.0      394.0          9.7    3.0
# 1              88.0      361.0         11.0    3.0
# 2              50.0      199.0         11.7    4.0
# 3              96.0      269.0         10.7    3.0
# 4              96.0      298.0         10.6    4.0
# ...             ...        ...          ...    ...
# 7900          224.0      344.0          9.9    2.0
# 7901           78.0      277.0         10.0    4.0
# 7902           62.0      200.0         12.7    2.0
# 7903          118.0      221.0         10.6    4.0
# 7904           85.0      336.0         10.3    3.0
#
# [7905 rows x 18 columns]

# %%
ss_cats = ["Bilirubin","Cholesterol","Albumin","Copper","Alk_Phos","SGOT","Tryglicerides","Platelets","Prothrombin"]
ss = StandardScaler()
X_train[ss_cats] = ss.fit_transform(X_train[ss_cats])

le = LabelEncoder()
y_train = pd.DataFrame(le.fit_transform(y_train))

# %% [markdown]
# # Split Data

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.2, stratify=y_train)

# %% [markdown]
# # XGBoost Classifer

# %%
param_grid = {
    "eta":[0.01, 0.02, 0.05, 0.1, 0.2],
    "max_depth":list(range(3,11)),
    "colsample_bytree":[0.5,1],
    "objective":["multi:softprob"]
}
xgb_grid = GridSearchCV(XGBClassifier(), param_grid, n_jobs=-1)
xgb_grid.fit(X_train, y_train)
xgb_pred = pd.DataFrame(xgb_grid.predict_proba(X_valid))
print(xgb_pred)
# Out:
#              0         1         2
# 0     0.989372  0.000735  0.009892
# 1     0.833941  0.103677  0.062382
# 2     0.986767  0.000460  0.012772
# 3     0.994630  0.000939  0.004431
# 4     0.012459  0.002849  0.984691
# ...        ...       ...       ...
# 1576  0.400094  0.512257  0.087649
# 1577  0.984211  0.000567  0.015222
# 1578  0.743720  0.019092  0.237188
# 1579  0.966413  0.002615  0.030972
# 1580  0.739873  0.049127  0.211000
#
# [1581 rows x 3 columns]

# %% [markdown]
# # Tensorflow

# %%
def train_model_split(X_train, y_train, num_nodes, dropout_prob, learning_rate, batch_size, epochs):
    neuralnet = tf.keras.Sequential([
        tf.keras.layers.Dense(num_nodes, activation="relu", input_shape=(18,)),
        tf.keras.layers.Dropout(dropout_prob),
        tf.keras.layers.Dense(num_nodes, activation="relu"),
        tf.keras.layers.Dropout(dropout_prob),
        tf.keras.layers.Dense(1, activation="sigmoid")
    ])
    neuralnet.compile(optimizer=tf.keras.optimizers.Adam(learning_rate),
                     loss="binary_crossentropy",
                     metrics=["accuracy"])
    history = neuralnet.fit(X_train,
                            y_train,
                            epochs=epochs,
                            batch_size=batch_size,
                            validation_split=0.2,
                            verbose=0
                           )
    return neuralnet, history

# %%
def train_model_data(X_train, y_train, num_nodes, dropout_prob, learning_rate, batch_size, epochs):
    neuralnet = tf.keras.Sequential([
        tf.keras.layers.Dense(num_nodes, activation="relu", input_shape=(18,)),
        tf.keras.layers.Dropout(dropout_prob),
        tf.keras.layers.Dense(num_nodes, activation="relu"),
        tf.keras.layers.Dropout(dropout_prob),
        tf.keras.layers.Dense(1, activation="sigmoid")
    ])
    neuralnet.compile(optimizer=tf.keras.optimizers.Adam(learning_rate),
                     loss="binary_crossentropy",
                     metrics=["accuracy"])
    history = neuralnet.fit(X_train,
                            y_train,
                            epochs=epochs,
                            batch_size=batch_size,
                            validation_data=(X_valid, y_valid),
                            verbose=0
                           )
    return neuralnet, history

# %%
least_validation_loss_split = float("inf")
least_validation_loss_data = float("inf")
least_loss_model_split = None
least_loss_model_data = None

epochs = 100
for num_nodes in [16,32,64]:
  for dropout_prob in [0,0.2]:
    for learning_rate in [0.01,0.005,0.001]:
      for batch_size in [32,64,128]:
        print(f"nodes: {num_nodes}, dropout: {dropout_prob}, learning rate: {learning_rate}, batch size: {batch_size}")
        print("validation_split = 0.2")
        model,history = train_model_split(X_train,y_train,num_nodes,dropout_prob,learning_rate,batch_size,epochs)
        val_loss, val_accuracy = model.evaluate(X_valid,y_valid)
        if val_loss < least_validation_loss_split:
          least_validation_loss_split = val_loss
          least_loss_model_split = model

        print("validation_data = (X_valid,y_valid)")
        model,history = train_model_data(X_train,y_train,num_nodes,dropout_prob,learning_rate,batch_size,epochs)
        val_loss, val_accuracy = model.evaluate(X_valid,y_valid)
        if val_loss < least_validation_loss_data:
          least_validation_loss_data = val_loss
          least_loss_model_data = model
# Out:
# nodes: 16, dropout: 0, learning rate: 0.01, batch size: 32
# validation_split = 0.2
# 50/50 [==============================] - 0s 1ms/step - loss: -4683923456.0000 - accuracy: 0.2049
# validation_data = (X_valid,y_valid)
# 50/50 [==============================] - 0s 2ms/step - loss: -2472321536.0000 - accuracy: 0.4194
# nodes: 16, dropout: 0, learning rate: 0.01, batch size: 64
# validation_split = 0.2
# 50/50 [==============================] - 0s 2ms/step - loss: -1020773568.0000 - accuracy: 0.3030
# validation_data = (X_valid,y_valid)
# 50/50 [==============================] - 0s 2ms/step - loss: -5031181824.0000 - accuracy: 0.4257
# nodes: 16, dropout: 0, learning rate: 0.01, batch size: 128
# validation_split = 0.2
# 50/50 [==============================] - 0s 1ms/step - loss: -99938648.0000 - accuracy: 0.3112
# validation_data = (X_valid,y_valid)
# 50/50 [==============================] - 0s 2ms/step - loss: -1766684032.0000 - accuracy: 0.1442
# nodes: 16, dropout: 0, learning rate: 0.005, batch size: 32
# validation_split = 0.2
# 50/50 [==============================] - 0s 1ms/step - loss: -812541760.0000 - accuracy: 0.2935
# validation_data = (X_valid,y_valid)
# 50/50 [==============================] - 0s 2ms/step - loss: -2411013888.0000 - accuracy: 0.2834
# nodes: 16, dropout: 0, learning rate: 0.005, batch size: 64
# validation_split = 0.2
# 50/50 [==============================] - 0s 2ms/step - loss: -227328576.0000 - accuracy: 0.2555
# validation_data = (X_valid,y_valid)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 20
#      17   least_loss_model_split = model
#      19 print("validation_data = (X_valid,y_valid)")
# ---> 20 model,history = train_model_data(X_train,y_train,num_nodes,dropout_prob,learning_rate,batch_size,epochs)
#      21 val_loss, val_accuracy = model.evaluate(X_valid,y_valid)
#      22 if val_loss < least_validation_loss_data:
#
# Cell In[13], line 12, in train_model_data(X_train, y_train, num_nodes, dropout_prob, learning_rate, batch_size, epochs)
#       2 neuralnet = tf.keras.Sequential([
#       3     tf.keras.layers.Dense(num_nodes, activation="relu", input_shape=(18,)),
#       4     tf.keras.layers.Dropout(dropout_prob),
#    (...)
#       7     tf.keras.layers.Dense(1, activation="sigmoid")
#       8 ])
#       9 neuralnet.compile(optimizer=tf.keras.optimizers.Adam(learning_rate),
#      10                  loss="binary_crossentropy",
#      11                  metrics=["accuracy"])
# ---> 12 history = neuralnet.fit(X_train,
#      13                         y_train,
#      14                         epochs=epochs,
#      15                         batch_size=batch_size,
#      16                         validation_data=(X_valid, y_valid),
#      17                         verbose=0
#      18                        )
#      19 return neuralnet, history
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:147, in TracingCompiler.__call__(self, *args, **kwargs)
#     144 """Calls a graph function specialized to the inputs."""
#     145 with self._lock:
#     146   (concrete_function,
# --> 147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
#     148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:359, in TracingCompiler._maybe_define_function(self, args, kwargs)
#     353 current_func_context = function_context.make_function_context()
#     355 # cache_key_deletion_observer is useless here. It's based on all captures.
#     356 # A new cache key will be built later when saving ConcreteFunction because
#     357 # only active captures should be saved.
#     358 lookup_func_type, lookup_func_context = (
# --> 359     self._function_spec.make_canonicalized_monomorphic_type(
#     360         args, kwargs, captures))
#     361 concrete_function = self._function_cache.lookup(current_func_context,
#     362                                                 lookup_func_type)
#     363 if concrete_function is not None:
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/function_spec.py:324, in FunctionSpec.make_canonicalized_monomorphic_type(self, args, kwargs, captures)
#     316   captures = dict()
#     318 kwargs = {
#     319     function_type_lib.sanitize_arg_name(name): value
#     320     for name, value in kwargs.items()
#     321 }
#     323 _, function_type, type_context = (
# --> 324     function_type_lib.canonicalize_to_monomorphic(
#     325         args, kwargs, self.default_values, captures, self.function_type
#     326     )
#     327 )
#     329 return function_type, type_context
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/core/function/polymorphism/function_type.py:462, in canonicalize_to_monomorphic(args, kwargs, default_values, captures, polymorphic_type)
#     456       parameters.append(
#     457           _make_validated_mono_param(kwarg_name, arg[kwarg_name],
#     458                                      Parameter.KEYWORD_ONLY, type_context,
#     459                                      poly_parameter.type_constraint))
#     460   else:
#     461     parameters.append(
# --> 462         _make_validated_mono_param(name, arg, poly_parameter.kind,
#     463                                    type_context,
#     464                                    poly_parameter.type_constraint))
#     466 capture_types = collections.OrderedDict()
#     467 for name, value in captures.items():
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/core/function/polymorphism/function_type.py:402, in _make_validated_mono_param(name, value, kind, type_context, poly_type)
#     398 def _make_validated_mono_param(
#     399     name, value, kind, type_context, poly_type
#     400 ) -> Parameter:
#     401   """Generates and validates a parameter for Monomorphic FunctionType."""
# --> 402   mono_type = trace_type.from_value(value, type_context)
#     404   if poly_type and not mono_type.is_subtype_of(poly_type):
#     405     raise TypeError(f"Parameter `{name}` was expected to be of type "
#     406                     f"{poly_type} but is {mono_type}")
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/core/function/trace_type/trace_type_builder.py:142, in from_value(value, context)
#     140 if context.is_legacy_signature and isinstance(value, trace.TraceType):
#     141   return value
# --> 142 elif isinstance(value, trace.SupportsTracingProtocol):
#     143   generated_type = value.__tf_tracing_type__(context)
#     144   if not isinstance(generated_type, trace.TraceType):
#
# File /opt/conda/lib/python3.10/typing.py:1502, in _ProtocolMeta.__instancecheck__(cls, instance)
#    1493 if (
#    1494     getattr(cls, '_is_protocol', False) and
#    1495     not getattr(cls, '_is_runtime_protocol', False) and
#    1496     not _allow_reckless_class_checks(depth=2)
#    1497 ):
#    1498     raise TypeError("Instance and class checks can only be used with"
#    1499                     " @runtime_checkable protocols")
#    1501 if ((not getattr(cls, '_is_protocol', False) or
# -> 1502         _is_callable_members_only(cls)) and
#    1503         issubclass(instance.__class__, cls)):
#    1504     return True
#    1505 if cls._is_protocol:
#
# File /opt/conda/lib/python3.10/typing.py:1427, in _is_callable_members_only(cls)
#    1425 def _is_callable_members_only(cls):
#    1426     # PEP 544 prohibits using issubclass() with protocols that have non-method members.
# -> 1427     return all(callable(getattr(cls, attr, None)) for attr in _get_protocol_attrs(cls))
#
# File /opt/conda/lib/python3.10/typing.py:1419, in _get_protocol_attrs(cls)
#    1417     continue
#    1418 annotations = getattr(base, '__annotations__', {})
# -> 1419 for attr in list(base.__dict__.keys()) + list(annotations.keys()):
#    1420     if not attr.startswith('_abc_') and attr not in EXCLUDED_ATTRIBUTES:
#    1421         attrs.add(attr)
#
# KeyboardInterrupt:

# %% [markdown]
# Idk why Tensorflow is performing so poorly and I'm kind of lazy to debug 🤔.

# %% [markdown]
# # Test Data

# %%
raw_test_data
# Out:
#          id  N_Days             Drug    Age Sex Ascites Hepatomegaly Spiders  \
# 0      7905    3839  D-penicillamine  19724   F       N            Y       N
# 1      7906    2468  D-penicillamine  14975   F       N            N       N
# 2      7907      51          Placebo  13149   F       N            Y       N
# 3      7908    2330  D-penicillamine  20510   F       N            N       N
# 4      7909    1615  D-penicillamine  21904   F       N            Y       N
# ...     ...     ...              ...    ...  ..     ...          ...     ...
# 5266  13171    2870          Placebo  12279   F       N            N       N
# 5267  13172    1770          Placebo  24803   F       N            N       N
# 5268  13173    3707  D-penicillamine  16990   F       N            Y       N
# 5269  13174    1216          Placebo  11773   F       N            N       N
# 5270  13175    2272  D-penicillamine  21600   F       N            N       N
#
#      Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 0        N        1.2        546.0     3.37    65.0    1636.0  151.90
# 1        N        1.1        660.0     4.22    94.0    1257.0  151.90
# 2        Y        2.0        151.0     2.96    46.0     961.0   69.75
# 3        N        0.6        293.0     3.85    40.0     554.0  125.55
# 4        N        1.4        277.0     2.97   121.0    1110.0  125.00
# ...    ...        ...          ...      ...     ...       ...     ...
# 5266     N        1.3        302.0     3.43    75.0    1345.0  145.00
# 5267     N        0.5        219.0     4.09   121.0     663.0   79.05
# 5268     N        0.8        315.0     4.09    13.0    1637.0  170.50
# 5269     N        0.7        329.0     3.80    52.0     678.0   57.00
# 5270     N        2.0        232.0     3.42    18.0    1636.0  170.50
#
#       Tryglicerides  Platelets  Prothrombin  Stage
# 0              90.0      430.0         10.6    2.0
# 1             155.0      227.0         10.0    2.0
# 2             101.0      213.0         13.0    4.0
# 3              56.0      270.0         10.6    2.0
# 4             126.0      221.0          9.8    1.0
# ...             ...        ...          ...    ...
# 5266           44.0      181.0         10.6    3.0
# 5267           94.0      311.0          9.7    3.0
# 5268           70.0      426.0         10.9    3.0
# 5269          126.0      306.0         10.2    1.0
# 5270           83.0      213.0         13.6    2.0
#
# [5271 rows x 19 columns]

# %%
test_data = convert_cat(raw_test_data.drop(columns=["id"]), le_cats)
ss = StandardScaler()
test_data[ss_cats] = ss.fit_transform(test_data[ss_cats])

# %%
y_pred = pd.DataFrame(xgb_grid.predict_proba(test_data))
y_pred.rename(columns = {0:"Status_C", 1:"Status_CL", 2:"Status_D"}, inplace=True)
print(y_pred)
# Out:
#       Status_C  Status_CL  Status_D
# 0     0.581837   0.012583  0.405579
# 1     0.794302   0.135331  0.070368
# 2     0.021444   0.012666  0.965890
# 3     0.983463   0.002006  0.014530
# 4     0.937892   0.014538  0.047570
# ...        ...        ...       ...
# 5266  0.974090   0.011070  0.014840
# 5267  0.986944   0.002436  0.010620
# 5268  0.953538   0.002780  0.043683
# 5269  0.995082   0.002298  0.002620
# 5270  0.204976   0.005953  0.789071
#
# [5271 rows x 3 columns]

# %%
final = pd.concat([raw_test_data["id"], y_pred], axis=1)
final.to_csv("submission.csv", index=False)
